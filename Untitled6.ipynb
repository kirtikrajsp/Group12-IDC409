# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
import re
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

print("Fetching main faculty page...")
data = requests.get('https://www.iiserkol.ac.in/web/en/people/faculty/dbs/')
soup = BeautifulSoup(data.content, "html.parser")

# Collecting faculty profile URLs
urls = [link['href'] for link in soup.find_all('a')]
urls = [url for url in urls if '/web/en/people/faculty/dbs/' in url]
link = 'https://www.iiserkol.ac.in'
faculty_websites = list(set([link + url for url in urls]))
print(f"Found {len(faculty_websites)} faculty profile URLs.")
# Out:
# Fetching main faculty page...
# Found 27 faculty profile URLs.

# %%
all_data = []
print("Scraping individual faculty pages...")

for faculty_url in faculty_websites:
    try:
        data = requests.get(faculty_url)
        data.raise_for_status()
        soup = BeautifulSoup(data.content, "html.parser")

        # Get faculty name
        name = soup.find_all('h3')
        faculty_name = [name.text for name in name]
        faculty_name = faculty_name[3].strip() if len(faculty_name) > 3 else None

        if not faculty_name:
            print(f"Skipping URL (could not find name): {faculty_url}")
            continue

        print(f"Processing: {faculty_name}")

        # Initialize profile dictionary
        profile_data = {
            "Name": faculty_name,
            "Positions": None,
            "Academic Background": None,
            "PhD": None,
            "PhD Year": None,
            "Research Interest": None,
            "Awards and Honors": None,
            "Number of awards": None,
        }

        # Get main profile content
        content = soup.find_all('div', class_='col-md-12 innerdiv')

        for section in content:
            section_text = section.get_text(separator="\n", strip=True)

            if 'Positions:' in section_text:
                profile_data["Positions"] = re.sub(r'Positions:\s+', '', section_text)

            elif 'Academic Background:' in section_text:
                profile_data["Academic Background"] = re.sub(r'Academic Background:\s+', '', section_text)

                # Try to extract PhD info from this section
                c = re.search(r"\d{4}", section_text) # Look for a 4-digit year
                if c:
                    x = c.start()
                    profile_data["PhD Year"] = section_text[x:x+4]
                    if 'PhD' in section_text or 'phd' in section_text or 'Ph.D' in section_text:
                        phd_text = section_text[21:x-1].strip(" ,")
                        profile_data["PhD"] = phd_text

            elif 'Research Interest:' in section_text:
                profile_data["Research Interest"] = re.sub(r'Research Interest:\s+', '', section_text)


            elif 'Awards and Honors:' in section_text:
                profile_data["Awards and Honors"] = re.sub(r'Awards and Honors:\s+', '', section_text)
                try:
                    award_count = (section_text.count('20') + section_text.count('19') -
                                   section_text.count('2020') - section_text.count('2019'))
                    profile_data["Number of awards"] = award_count
                except Exception:
                    profile_data["Number of awards"] = None # No awards found


        all_data.append(profile_data)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {faculty_url}: {e}")
        continue

print("Scraping complete.")
# Out:
# Scraping individual faculty pages...
# Processing: Neelanjana Sengupta
# Processing: Rupak Datta
# Processing: Rahul Das
# Processing: Dipjyoti Das
# Processing: Partha Pratim Datta
# Processing: Amit Kumar Mandal
# Processing: Annagiri Sumana
# Processing: Anindita Bhadra
# Processing: Tapas Kumar Sengupta
# Processing: Arnab Gupta
# Processing: Babu Sudhamalla
# Processing: Radhika Venkatesan
# Processing: Bidisha Sinha
# Processing: Rituparna Sinha Roy
# Processing: Supratim Datta
# Processing: Punyasloke Bhadury
# Processing: Partho Sarothi Ray
# Processing: Mohit Prasad
# Processing: Robert John Chandran
# Processing: Sunil Kumar Khare
# Processing: Sreeramaiah Gangappa
# Processing: Malancha Ta
# Processing: Sankar Maiti
# Processing: Sumit Sen Santara
# Processing: Jayasri Das Sarma
# Processing: Anuradha Bhat
# Processing: Amirul Islam Mallick
# Scraping complete.

# %%
print("Connecting to database and saving data...")
conn = sqlite3.connect("faculty_data.db")
cursor = conn.cursor()

# Drop the table if it already exists
cursor.execute("DROP TABLE IF EXISTS Faculty")

# Create the new table
cursor.execute('''
CREATE TABLE Faculty (
    Name TEXT,
    Positions TEXT,
    Academic_Background TEXT,
    PhD TEXT,
    PhD_Year INTEGER,
    Research_Interest TEXT,
    Awards_and_Honors TEXT,
    Number_of_awards INTEGER,
)
''')

# Insert data into the table
for profile in all_data:
    cursor.execute('''
    INSERT INTO Faculty (
        Name, Positions, Academic_Background, PhD, PhD_Year, Research_Interest,
        Awards_and_Honors, Number_of_awards
    ) VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    ''', (
        profile["Name"],
        profile["Positions"],
        profile["Academic Background"],
        profile["PhD"],
        profile["PhD Year"],
        profile["Research Interest"],
        profile["Awards and Honors"],
        profile["Number of awards"]
    ))

# Commit changes
conn.commit()
print("Data saved to faculty_data.db")
# Out:
# Connecting to database and saving data...
# Data saved to faculty_data.db

# %%
print("Loading data into pandas DataFrame...")
# Read data from SQL back into a pandas DataFrame
df = pd.read_sql_query("SELECT * FROM Faculty", conn)

# Close the database connection
# conn.close() # Removed this line to keep the connection open

# Define list of Indian locations
Indian_cities = [
    "Adilabad", "Adoni", "Agartala", "Agra", "Ahmedabad", "Ahmednagar", "Aizawl", "Ajmer", "Akola",
"Aligarh", "Allahabad", "Alwar", "Amravati", "Ambattur", "Amritsar", "Anand", "Anantapur",
"Andaman and Nicobar Islands", "Andhra Pradesh", "Arrah", "Arunachal Pradesh", "Asansol",
"Aurangabad", "Aurangabad (Bihar)", "Avadi", "Bally", "Balasore", "Bareilly", "Baramati",
"Baramulla", "Barasat", "Bardhaman", "Baripada", "Barmer", "Bathinda", "Begusarai", "Belgaum",
"Bellary", "Bengaluru", "Berhampur", "Bhagalpur", "Bhavnagar", "Bhilai", "Bhilwara", "Bhiwani",
"Bhopal", "Bhubaneswar", "Bhuj", "Bihar", "Bihar Sharif", "Bijapur", "Bilaspur", "Bilaspur (HP)",
"BITS Goa", "BITS Hyderabad", "BITS Pilani", "Bokaro", "Bombay", "Brahmapur", "Burdwan",
"Calcutta", "Chandigarh", "Chandrapur", "Chapra", "Chennai", "Chhattisgarh", "Chittoor", "Coimbatore",
"Cuddalore", "Cuttack", "Darbhanga", "Darjeeling", "Davanagere", "Dadra and Nagar Haveli and Daman and Diu",
"Dehradun", "Deoghar", "Delhi", "Dewas", "Dhanbad", "Dharwad", "Dhule", "Dibrugarh", "Dindigul",
"Diu", "Dumka", "Durg", "Durgapur", "Eluru", "Erode", "Faridabad", "Farrukhabad", "Firozabad",
"Gandhinagar", "Gaya", "Ghaziabad", "Giridih", "Goa", "Gopalganj", "Gorakhpur", "Gujarat",
"Gulbarga", "Guntur", "Guwahati", "Gwalior", "Hamirpur", "Haldia", "Haldwani", "Hapur", "Haridwar",
"Haryana", "Hazaribagh", "Himachal Pradesh", "Hindupur", "Hoshangabad", "Howrah", "Hubli-Dharwad",
"Hosur", "Hyderabad", "Ichalkaranji", "IIIT Allahabad", "IIIT Hyderabad", "IISc", "IISER Berhampur",
"IISER Bhopal", "IISER Kolkata", "IISER Mohali", "IISER Pune", "IISER Tirupati", "Imphal",
"Indore", "India", "Indian", "Jabalpur", "Jagdalpur", "Jadavpur", "Jaipur", "Jaisalmer", "Jalgaon",
"Jalna", "Jalpaiguri", "Jammu and Kashmir", "Jamnagar", "Jamui", "Jamshedpur", "Jhansi", "Jharkhand",
"Jhunjhunu", "JNU", "Jodhpur", "Junagadh", "Kadapa", "Kakinada", "Kalyan-Dombivli", "Kalyani",
"Kanchipuram", "Kanpur", "Kanyakumari", "Karaikal", "Karimnagar", "Karur", "Karnal", "Karnataka",
"Kathua", "Khammam", "Kharagpur", "Kochi", "Kolhapur", "Kolkata", "Kollam", "Korba", "Kota",
"Kothagudem", "Kozhikode", "Kulti", "Kumbakonam", "Kurnool", "Ladakh", "Lakshadweep", "Latur",
"Loni", "Lovely Professional University", "Lucknow", "Ludhiana", "Machilipatnam", "Madurai", "Madras",
"Mahbubnagar", "Maheshtala", "Malda", "Malegaon", "Mangalore", "Manipal", "Manipur", "Mandi",
"Mathura", "Mau", "Meerut", "Meghalaya", "Moradabad", "Morena", "Mumbai", "Muzaffarnagar",
"Muzaffarpur", "Mysuru", "Nagaland", "Nagpur", "Nainital", "Nanded", "Nashik", "Navi Mumbai",
"Nellore", "New Delhi", "NIT Calicut", "NIT Surathkal", "NIT Trichy", "NIT Warangal", "Nizamabad",
"Noida", "Odisha", "Ongole", "Ozhukarai", "Palakkad", "Panihati", "Panipat", "Parbhani", "Patiala",
"Patna", "Puducherry", "Pune", "Purnia", "Punjab", "Rajasthan", "Raiganj", "Raipur", "Rajahmundry",
"Rajkot", "Ranchi", "Rampur", "Ratlam", "Ratnagiri", "Rewa", "Rishikesh", "Ropar", "Roorkee",
"Rourkela", "Sagar", "Salem", "Samastipur", "Sambalpur", "Sangli", "Satara", "Satna", "Saharanpur",
"Shahjahanpur", "Shimla", "Shillong", "Shimoga", "Sikar", "Silchar", "Siliguri", "Siwan", "Solan",
"Solapur", "Sonipat", "South Dumdum", "Srikakulam", "Srinagar", "SRM Chennai", "Surat", "Tamil Nadu",
"Tanjavur", "Telangana", "Thanjavur", "Thiruvananthapuram", "Thrissur", "Tiruchirappalli", "Tirunelveli",
"Tirupati", "Tiruppur", "Tripura", "Tumkur", "Udaipur", "Ujjain", "Ulhasnagar", "Una", "Uttar Pradesh",
"Uttarakhand", "Vadodara", "Varanasi", "Vasai-Virar", "Vellore", "Vijayawada", "Visakhapatnam",
"Vizianagaram", "VIT Vellore", "Warangal", "Wardha", "West Bengal"

]

# Function to classify PhD institution
def institution(phd_string):
    if phd_string is None:
        return None
    for institute in Indian_cities:
        if institute in str(phd_string):
            return "India"
    return "Abroad"

# Apply the function to create a new column
df['PhD_Institution'] = df['PhD'].apply(institution)

# Create filtered DataFrames for further analysis
df_filtered = df[df['PhD_Institution'].notna()]
df_yrAw = df.dropna(subset=["Number_of_awards", "PhD_Year"])

# Prepare data for potential plotting or curve fitting
years = df_yrAw["PhD_Year"]
Aws = df_yrAw["Number_of_awards"]

print("Analysis complete. DataFrame 'df' is ready.")
print("\nDataFrame Head:")
print(df.head())

print("\nPhD Institution Counts:")
print(df['PhD_Institution'].value_counts())
# Out:
# Loading data into pandas DataFrame...
# Analysis complete. DataFrame 'df' is ready.
#
# DataFrame Head:
#                   Name                                  Research_Interest  \
# 0  Neelanjana Sengupta  The key goal of our research is to understand ...
# 1          Rupak Datta  Lysosomes are cell's recycling and waste dispo...
# 2            Rahul Das  The main interest of our laboratory is to unde...
# 3         Dipjyoti Das  We try to understand how complex behaviors eme...
# 4  Partha Pratim Datta  We are studying the molecular basis of Antimic...
#
#                                  Academic_Background  \
# 0  Ph.D (Chemical and Materials Physics), UCI (Un...
# 1  PhD (Biochemistry & Molecular Biology), Indian...
# 2  Ph.D. (Structural Biology),   (McMaster Univer...
# 3  PhD (Physics), IIT Bombay, 2014\nMSc (Physics)...
# 4  PhD (Molecular Biology), IICB (Jadavpur Univer...
#
#                                                  PhD  PhD_Year  \
# 0  Ph.D (Chemical and Materials Physics), UCI (Un...      2008
# 1  PhD (Biochemistry & Molecular Biology), Indian...      2006
# 2  Ph.D. (Structural Biology),   (McMaster Univer...      2008
# 3                          PhD (Physics), IIT Bombay      2014
# 4  PhD (Molecular Biology), IICB (Jadavpur Univer...      2002
#
#                                            Positions  \
# 0  Professor, IISER Kolkata      (current)\nAssis...
# 1  Professor, IISER Kolkata      (current)\nHead,...
# 2  Associate Professor, IISER Kolkata      (curre...
# 3  Assistant Professor, IISER Kolkata      (curre...
# 4  Professor, IISER Kolkata      (current)\nAssoc...
#
#                                    Awards_and_Honors  Number_of_awards  \
# 0  Bronze Medal\nfrom Chemical research Society o...               2.0
# 1  Young Investigator Award\nfrom International C...               4.0
# 2  Early Career Award\nfrom SERB (2016)\nRamaling...               6.0
# 3  SERB International Research Experience Fellows...               3.0
# 4  Sir JC Bose Memorial Lecture\nfrom BCKV and DB...               3.0
#
#                                         Publications  No_of_publications  \
# 0                                                                      0
# 1                                                                      0
# 2  Chakraborty, Manas Pratim; Bhattacharyya, Sudi...                  30
# 3  Banerjee, Binayak; Satheesan, Sankeert and Das...                  13
# 4                                                                      0
#
#   PhD_Institution
# 0          Abroad
# 1           India
# 2          Abroad
# 3           India
# 4           India
#
# PhD Institution Counts:
# PhD_Institution
# India     21
# Abroad     6
# Name: count, dtype: int64

# %%
import pandas as pd
import sqlite3
import tabulate
import numpy as np # Import numpy

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# --- 2. Create a list of the columns you want to see ---
columns_from_image = [
    'Name',
    'Positions',
    'Academic_Background',
    'PhD',
    'PhD_Year',
    'Research_Interest',
    'Awards_and_Honors',
    'Number_of_awards'
]

df_to_print = df[columns_from_image].copy() # Create a copy to avoid SettingWithCopyWarning

# Fill NaN values with empty strings to prevent errors with tabulate
df_to_print.fillna('', inplace=True)

# Convert all columns to string type for tabulate
for col in df_to_print.columns:
    df_to_print[col] = df_to_print[col].astype(str)

# --- 2. Define your fixed column widths ---
col_widths = [
    30, # Name
    40, # Research_Interest
    40, # Academic_Background
    40, # PhD
    10, # PhD_Year
    40, # Positions
    40, # Awards_and_Honors
    10  # Number_of_awards
]

print(tabulate.tabulate(
    df_to_print,
    headers='keys',
    tablefmt='grid',
    maxcolwidths=col_widths,
    showindex=False
))
# Out:
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Name                 | Positions                                | Academic_Background                      | PhD                                      |   PhD_Year | Research_Interest                        | Awards_and_Honors                        | Number_of_awards   |
# +======================+==========================================+==========================================+==========================================+============+==========================================+==========================================+====================+
# | Neelanjana Sengupta  | Professor, IISER Kolkata      (current)  | Ph.D (Chemical and Materials Physics),   | Ph.D (Chemical and Materials Physics),   |       2008 | The key goal of our research is to       | Bronze Medal from Chemical research      | 2.0                |
# |                      | Assistant Professor, IISER Kolkata       | UCI (University of California, Irvine),  | UCI (University of California, Irvine)   |            | understand and predict the behaviour of  | Society of India (2024) Humboldt         |                    |
# |                      | (2016 - 2019) Associate Professor,       | 2008, Advisor: Douglas J. Tobias         |                                          |            | biological systems at the molecular      | Experienced Researcher Fellowship from   |                    |
# |                      | Indian Institute of Science Education    |                                          |                                          |            | level using ‘bottoms up’ approaches.     | Alexander von Humboldt Foundation,       |                    |
# |                      | and Research Kolkata     (2019 - 2019)   |                                          |                                          |            | This involves harnessing the power of    | Germany (2021)                           |                    |
# |                      | Scientist, National Chemical Laboratory  |                                          |                                          |            | modern-day computers to investigate the  |                                          |                    |
# |                      | (NCL) Pune     (2008 - 2016)             |                                          |                                          |            | structure, dynamics and thermodynamics   |                                          |                    |
# |                      |                                          |                                          |                                          |            | of biological complexes at the atomistic |                                          |                    |
# |                      |                                          |                                          |                                          |            | level in their closest native milieu, as |                                          |                    |
# |                      |                                          |                                          |                                          |            | well as under chemically perturbing      |                                          |                    |
# |                      |                                          |                                          |                                          |            | environmental conditions. Advanced,      |                                          |                    |
# |                      |                                          |                                          |                                          |            | state-of-the-art molecular simulations,  |                                          |                    |
# |                      |                                          |                                          |                                          |            | combined with tools based on the         |                                          |                    |
# |                      |                                          |                                          |                                          |            | principles of equilibrium and non-       |                                          |                    |
# |                      |                                          |                                          |                                          |            | equilibrium statistical mechanics,       |                                          |                    |
# |                      |                                          |                                          |                                          |            | offers us a powerful ‘computational      |                                          |                    |
# |                      |                                          |                                          |                                          |            | microscope’ to investigate a variety of  |                                          |                    |
# |                      |                                          |                                          |                                          |            | biological problams from a fundamental   |                                          |                    |
# |                      |                                          |                                          |                                          |            | as well as from an applied perspective.  |                                          |                    |
# |                      |                                          |                                          |                                          |            | Extensive collaborations with            |                                          |                    |
# |                      |                                          |                                          |                                          |            | biochemists, disease biologists and      |                                          |                    |
# |                      |                                          |                                          |                                          |            | material chemists are carried out. We    |                                          |                    |
# |                      |                                          |                                          |                                          |            | are increasingly developing analytical   |                                          |                    |
# |                      |                                          |                                          |                                          |            | tools that harness the advantages of     |                                          |                    |
# |                      |                                          |                                          |                                          |            | machine learning (ML) and artificial     |                                          |                    |
# |                      |                                          |                                          |                                          |            | intelligence methods (AI).               |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Rupak Datta          | Professor, IISER Kolkata      (current)  | PhD (Biochemistry & Molecular Biology),  | PhD (Biochemistry & Molecular Biology),  |       2006 | Lysosomes are cell's recycling and waste | Young Investigator Award from            | 4.0                |
# |                      | Head, Department of Biological Sciences, | Indian Institute of Chemical Biology,    | Indian Institute of Chemical Biology     |            | disposal system, containing a battery    | International Congress of Human          |                    |
# |                      | IISER Kolkata     (2021 - 2024)          | 2006 M.Sc (Biochemistry), University of  |                                          |            | acid hydrolases that degrade a wide      | Genetics, Montreal (2011) Ramalingaswami |                    |
# |                      | Assistant & Associate Professor, IISER   | Calcutta, 2000                           |                                          |            | variety of macromolecules and cellular   | Fellowship from Department of            |                    |
# |                      | Kolkata     (2010 - 2021) Postdoctoral   |                                          |                                          |            | debris into reusable forms. In doing so, | Biotechnology, Government of India       |                    |
# |                      | Fellow, Department of Biochemistry &     |                                          |                                          |            | lysosomes play a vital role in           | (2011) Travel award from Protein Mis-    |                    |
# |                      | Molecular Biology, Saint Louis           |                                          |                                          |            | maintaining cellular homeostasis. They   | folding and Mis-processing in Disease    |                    |
# |                      | University     (2006 - 2010)             |                                          |                                          |            | also function as key cell signaling hubs | meeting, National Institutes of Health   |                    |
# |                      |                                          |                                          |                                          |            | for regulating processes such as         | (2009) Postdoctoral Presentation         |                    |
# |                      |                                          |                                          |                                          |            | nutrient sensing and energy metabolism.  | Finalist Award from American Society of  |                    |
# |                      |                                          |                                          |                                          |            | The overarching goal of our research is  | Human Genetics, San Diego (2007)         |                    |
# |                      |                                          |                                          |                                          |            | to understand the role of this           |                                          |                    |
# |                      |                                          |                                          |                                          |            | fascinating organelle in human health    |                                          |                    |
# |                      |                                          |                                          |                                          |            | and disease. The details about our       |                                          |                    |
# |                      |                                          |                                          |                                          |            | research can be found here:              |                                          |                    |
# |                      |                                          |                                          |                                          |            | https://bio.iiserkol.ac.in/?page_id=4480 |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Rahul Das            | Associate Professor, IISER Kolkata       | Ph.D. (Structural Biology),   (McMaster  | Ph.D. (Structural Biology),   (McMaster  |       2008 | The main interest of our laboratory is   | Early Career Award from SERB (2016)      | 6.0                |
# |                      | (current) Assistant Professor, IISER     | University, Canada), 2008 M.Tech.        | University, Canada)                      |            | to understand the mechanism of signal    | Ramalingaswami Re-entry Fellowship from  |                    |
# |                      | Kolkata     (2014 - 2021) Postdoctoral   | (Biotech and Biochem Engg),   (IIT       |                                          |            | transduction across the plasma membrane. | DBT (2016) CIHR Postdoctoral Fellowship  |                    |
# |                      | Fellow, University of California,        | Khargpur), 2000                          |                                          |            | Our research is focused on studying the  | from Canadian Institutes of Health       |                    |
# |                      | Berkeley     (2009 - 2014) Research      |                                          |                                          |            | allosteric regulation of two tyrosine    | Research  (2011) NSERC Postdoctoral      |                    |
# |                      | Associate, Wockhardt Research Centre     |                                          |                                          |            | kinases, ZAP-70, a membrane-associated   | Fellowship from Natural Sciences and     |                    |
# |                      | (2000 - 2001)                            |                                          |                                          |            | protein kinase found in T-Cells, and     | Engineering Research Council, Canada     |                    |
# |                      |                                          |                                          |                                          |            | transmembrane receptors like VEGF        | (2009) Impact Award from McMaster        |                    |
# |                      |                                          |                                          |                                          |            | receptors, respectively. Kinases are     | University, Canada (2007) Research       |                    |
# |                      |                                          |                                          |                                          |            | known to function as dynamic signaling   | Scholarship from McMaster University,    |                    |
# |                      |                                          |                                          |                                          |            | switches. However, they are not turned   | Canada (2004)                            |                    |
# |                      |                                          |                                          |                                          |            | on (active state) and off (inactive      |                                          |                    |
# |                      |                                          |                                          |                                          |            | state) by one factor. How kinases toggle |                                          |                    |
# |                      |                                          |                                          |                                          |            | between inactive conformations to an     |                                          |                    |
# |                      |                                          |                                          |                                          |            | active conformation has been the subject |                                          |                    |
# |                      |                                          |                                          |                                          |            | of many studies. It is believed that an  |                                          |                    |
# |                      |                                          |                                          |                                          |            | intricate circuitry of intra- and inter- |                                          |                    |
# |                      |                                          |                                          |                                          |            | molecular allosteric networks (mainly    |                                          |                    |
# |                      |                                          |                                          |                                          |            | through non-covalent interactions)       |                                          |                    |
# |                      |                                          |                                          |                                          |            | present in the regulatory and the        |                                          |                    |
# |                      |                                          |                                          |                                          |            | catalytic modules control the kinase     |                                          |                    |
# |                      |                                          |                                          |                                          |            | activity. Our laboratory is particularly |                                          |                    |
# |                      |                                          |                                          |                                          |            | interested to understand the role of     |                                          |                    |
# |                      |                                          |                                          |                                          |            | protein dynamics in modulating           |                                          |                    |
# |                      |                                          |                                          |                                          |            | extracellular signals transduction       |                                          |                    |
# |                      |                                          |                                          |                                          |            | across the plasma membrane. We use       |                                          |                    |
# |                      |                                          |                                          |                                          |            | spectroscopy techniques (like NMR        |                                          |                    |
# |                      |                                          |                                          |                                          |            | spectroscopy and fluorescence            |                                          |                    |
# |                      |                                          |                                          |                                          |            | spectroscopy) to study the structure and |                                          |                    |
# |                      |                                          |                                          |                                          |            | dynamics of the regulatory module of the |                                          |                    |
# |                      |                                          |                                          |                                          |            | membrane-associated kinases. We connect  |                                          |                    |
# |                      |                                          |                                          |                                          |            | the structural data to the biological    |                                          |                    |
# |                      |                                          |                                          |                                          |            | function by combining the biochemical    |                                          |                    |
# |                      |                                          |                                          |                                          |            | analysis and cell-based studies to find  |                                          |                    |
# |                      |                                          |                                          |                                          |            | out how they work.                       |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Dipjyoti Das         | Assistant Professor, IISER Kolkata       | PhD (Physics), IIT Bombay, 2014 MSc      | PhD (Physics), IIT Bombay                |       2014 | We try to understand how complex         | SERB International Research Experience   | 3.0                |
# |                      | (current) Postdoctoral Associate, Yale   | (Physics), IIT Bombay, 2009 BSc          |                                          |            | behaviors emerge in biological systems   | Fellowship from Science and Engineering  |                    |
# |                      | University, Connecticut,  USA     (2014  | (Physics), Jadavpur University, 2007     |                                          |            | at different scales of organizations,    | Research Board (Government of India)     |                    |
# |                      | - 2018)                                  |                                          |                                          |            | starting from the sub-cellular and       | (2022) SERB Early Career Award from      |                    |
# |                      |                                          |                                          |                                          |            | cellular scale to the tissue and         | Science and Engineering Research Board   |                    |
# |                      |                                          |                                          |                                          |            | organismic level. At all these scales,   | (Government of India) (2019)             |                    |
# |                      |                                          |                                          |                                          |            | biological systems are generally         | Ramalingaswami Re-entry Fellowship from  |                    |
# |                      |                                          |                                          |                                          |            | characterized by a large set of          | Department of Biotechnology (DBT),       |                    |
# |                      |                                          |                                          |                                          |            | interconnected physical and chemical     | Government of India. (2019)              |                    |
# |                      |                                          |                                          |                                          |            | processes that drive the system out of   |                                          |                    |
# |                      |                                          |                                          |                                          |            | equilibrium. Our method of investigation |                                          |                    |
# |                      |                                          |                                          |                                          |            | of such systems is theoretical and       |                                          |                    |
# |                      |                                          |                                          |                                          |            | computational model building  (using     |                                          |                    |
# |                      |                                          |                                          |                                          |            | tools of statistical physics) and data   |                                          |                    |
# |                      |                                          |                                          |                                          |            | analysis, in close collaboration with    |                                          |                    |
# |                      |                                          |                                          |                                          |            | experimental biologists. Some specific   |                                          |                    |
# |                      |                                          |                                          |                                          |            | areas of interest include: (1)           |                                          |                    |
# |                      |                                          |                                          |                                          |            | Biophysics and tissue mechanics in       |                                          |                    |
# |                      |                                          |                                          |                                          |            | embryonic developmental processes, (2)   |                                          |                    |
# |                      |                                          |                                          |                                          |            | Stochastic dynamics of cytoskeletal      |                                          |                    |
# |                      |                                          |                                          |                                          |            | filaments and molecular motors, (3)      |                                          |                    |
# |                      |                                          |                                          |                                          |            | Stochastic gene expression,  (4)         |                                          |                    |
# |                      |                                          |                                          |                                          |            | Population dynamics of interacting       |                                          |                    |
# |                      |                                          |                                          |                                          |            | micro-organisms,  (5) Models of          |                                          |                    |
# |                      |                                          |                                          |                                          |            | intracellular transport, and (6) Pattern |                                          |                    |
# |                      |                                          |                                          |                                          |            | formation in biology.                    |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Partha Pratim Datta  | Professor, IISER Kolkata      (current)  | PhD (Molecular Biology), IICB (Jadavpur  | PhD (Molecular Biology), IICB (Jadavpur  |       2002 | We are studying the molecular basis of   | Sir JC Bose Memorial Lecture from BCKV   | 3.0                |
# |                      | Associate Professor, IISER Kolkata       | University), 2002 MSc (Biotechnology)    | University)                              |            | Antimicrobial Resistance (AMR) and       | and DBT of WB (2025) Robert J. Colinas   |                    |
# |                      | (2018 - 2024) Assistant Professor, IISER | (Biotechnology, Molecular Biology, Plant |                                          |            | searching for new drug targets against   | Award for Outstanding Postdoctoral       |                    |
# |                      | Kolkata     (2009 - 2018) Research       | Molecular Biology, Microbiology), MKU,   |                                          |            | AMR. We are investigating the action     | Research, from Wadsworth Center, Albany, |                    |
# |                      | Scientist I, Wadsworth Center, NY State  | 1995 BSc(Ag) Hons (Biochemistry,         |                                          |            | mechanisms of an essential bacterial     | USA (2007) Young Scientist Award from    |                    |
# |                      | Dept. of Health, Albany, NY, USA         | Genetics, Agril. Chemistry), BCKV, 1993  |                                          |            | GTPase protein, CgtA (Obg), which could  | MEEGID (2000)                            |                    |
# |                      | (2008 - 2009) Research Affiliate,        |                                          |                                          |            | serve as a new drug target against AMR   |                                          |                    |
# |                      | Wadsworth Center, Albany, NY, USA        |                                          |                                          |            | in various bacteria. For this, we are    |                                          |                    |
# |                      | (2001 - 2008)                            |                                          |                                          |            | applying bacterial genetics, molecular   |                                          |                    |
# |                      |                                          |                                          |                                          |            | biology, biochemistry, microbiology,     |                                          |                    |
# |                      |                                          |                                          |                                          |            | structural biology, and various          |                                          |                    |
# |                      |                                          |                                          |                                          |            | computational tools. We also study       |                                          |                    |
# |                      |                                          |                                          |                                          |            | stress response and biofilm formation in |                                          |                    |
# |                      |                                          |                                          |                                          |            | bacteria. Furthermore, we are            |                                          |                    |
# |                      |                                          |                                          |                                          |            | investigating the action mechanisms of   |                                          |                    |
# |                      |                                          |                                          |                                          |            | several novel proteins recently          |                                          |                    |
# |                      |                                          |                                          |                                          |            | identified in our laboratory and are     |                                          |                    |
# |                      |                                          |                                          |                                          |            | also working to develop anti-bacterial   |                                          |                    |
# |                      |                                          |                                          |                                          |            | vaccines through collaborations. Vibrio, |                                          |                    |
# |                      |                                          |                                          |                                          |            | Mycobacteria, and Pseudomonas are some   |                                          |                    |
# |                      |                                          |                                          |                                          |            | of our model organisms. On the other     |                                          |                    |
# |                      |                                          |                                          |                                          |            | hand, we are conducting structure-       |                                          |                    |
# |                      |                                          |                                          |                                          |            | function studies (cryo-EM) on certain    |                                          |                    |
# |                      |                                          |                                          |                                          |            | plant viruses that cause significant     |                                          |                    |
# |                      |                                          |                                          |                                          |            | economic losses in India and globally.   |                                          |                    |
# |                      |                                          |                                          |                                          |            | We are also conducting cryo-EM studies   |                                          |                    |
# |                      |                                          |                                          |                                          |            | on some other molecular complexes.       |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Amit Kumar Mandal    | Professor, IISER Kolkata      (current)  | PhD (Biophysical Chemistry), Bose        | PhD (Biophysical Chemistry), Bose        |       2002 | Molecular Medicine - Structural Biology  | Centers of Innovation (COI) [www.waters. | 1.0                |
# |                      | Associate Professor, IISER-Kolkata       | Institute (Jadavpur University), 2002    | Institute (Jadavpur University)          |            | of proteins that are important in human  | com/waters/nav.htm?cid=10176245] from    |                    |
# |                      | (2019 - 2024) Professor, St. John's      | MSc (Physical Chemistry), Presidency     |                                          |            | diseases, Clinical Proteomics of         | WATERS, USA (2013)                       |                    |
# |                      | Research Institute, St. John's National  | College (University of Calcutta), 1992   |                                          |            | biological fluids and tissues from       |                                          |                    |
# |                      | Academy of Health Sciences, Bangalore    |                                          |                                          |            | patient sample, Imaging of clinically    |                                          |                    |
# |                      | (2011 - 2019) Associate Professor, St.   |                                          |                                          |            | important molecules in human tissues     |                                          |                    |
# |                      | John's Research Institute, St. John's    |                                          |                                          |            |                                          |                                          |                    |
# |                      | National Academy of Health Sciences,     |                                          |                                          |            |                                          |                                          |                    |
# |                      | Bangalore     (2007 - 2011) Postdoctoral |                                          |                                          |            |                                          |                                          |                    |
# |                      | Fellow, Indian Institute of Science,     |                                          |                                          |            |                                          |                                          |                    |
# |                      | Bangalore     (2005 - 2006) Postdoctoral |                                          |                                          |            |                                          |                                          |                    |
# |                      | Fellow, University of Texas Health       |                                          |                                          |            |                                          |                                          |                    |
# |                      | Science Center, San Antonio, Texas, USA  |                                          |                                          |            |                                          |                                          |                    |
# |                      | (2002 - 2003)                            |                                          |                                          |            |                                          |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Annagiri Sumana      | Professor, IISER Kolkata ( - ) Chairman  | PhD (Dominance Hierarchy in a social     | PhD (Dominance Hierarchy in a social     |       2002 | EvolutionEcologyAnimal Behaviour         | Emerging nations award from Animal       | 4.0                |
# |                      | - Department of Biological Sciences,     | wasp), Indian Institute of Science       | wasp), Indian Institute of Science       |            |                                          | Behaviour Society and International      |                    |
# |                      | Indian Institute of Science Education    | (Bangalore), 2002 MSc (Bioscience),      | (Bangalore)                              |            |                                          | Ethology conference, 2011 (2011) Junior  |                    |
# |                      | and Research, Kolkata (2012 - 2014)      | Hemagangotri - Hassan (Mysore            |                                          |            |                                          | Research Fellowship and eligibility for  |                    |
# |                      | Assistant Professor, Indian Institute of | University), 1995 Post Grad Diploma      |                                          |            |                                          | lectureship award from Council of        |                    |
# |                      | Science Education and Research, Kolkata  | (Ecology & Environment), Indian          |                                          |            |                                          | Scientific and and Industrial Research & |                    |
# |                      | (2008 - 2014) Post Doctoral Fellow,      | Institute of Ecology and Envirnom (New   |                                          |            |                                          | University Grants Commission (Government |                    |
# |                      | Tufts University (2002 - 2004)           | Delhi), 1994 BSc (Botany, Biochemistry & |                                          |            |                                          | of India) (1995) First Rank from Mysore  |                    |
# |                      |                                          | Zoology), Maharani's College (Mysore     |                                          |            |                                          | University (1995)                        |                    |
# |                      |                                          | University), 1993                        |                                          |            |                                          |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Anindita Bhadra      | Professor, IISER Kolkata      (current)  | PhD (Animal Behaviour), Centre for       | PhD (Animal Behaviour), Centre for       |       2008 | I work on the behavioural ecology of the | Editorial Board member from Animal       | 24.0               |
# |                      | Editorial Board member, Indian Academy   | Ecological Sciences (Indian Institute of | Ecological Sciences (Indian Institute of |            | Indian free-ranging dogs. I use the dogs | Behavior and Cognition Journal (2022)    |                    |
# |                      | of Sciences     (2025 - 2027) Associate  | Science, Bangalore), 2008, Thesis title: | Science, Bangalore)                      |            | as a model system to address various     | Community Gateway Advisor from Open      |                    |
# |                      | Professor, IISER Kolkata     (2019 -     | Queens and their Successors: The story   |                                          |            | questions in behavioural ecology         | Research Europe (2022) Academic Editor   |                    |
# |                      | 2025) Associate Dean IRO, Indian         | of Power in the Primitively Eusocial     |                                          |            | pertaining to aggression, mating,        | from PLoS ONE (2022) Member,             |                    |
# |                      | Institute of Science Education and       | Wasp Ropalidia marginata MSc (Zoology),  |                                          |            | parental care, foraging and social       | International advisory board from        |                    |
# |                      | Research Kolkata     (2019 - 2021) Co-   | Ballygunge Science College (Calcutta     |                                          |            | organization. I would like to use this   | IYBSSD2022 (2021) Janaki Ammal National  |                    |
# |                      | Chair, Global Young Academy     (2020 -  | University), 2001 BSc (Zoology),         |                                          |            | system to understand the evolution of    | Women Bioscientist Award from DBT (2021) |                    |
# |                      | 2021) Review Editor, Frontiers in        | Vivekananda College, Thakurpukur         |                                          |            | the dog-human relationship in nature.    | CoChair from Global Young Academy (2020) |                    |
# |                      | Behavioral and Evolutionary Ecology      | (Calcutta University), 1999              |                                          |            |                                          | Member of RSB from Royal Society of      |                    |
# |                      | (2016 - 2020) Member, Executive          |                                          |                                          |            |                                          | Biology (2019) Executive Committee       |                    |
# ...
# |                      |                                          |                                          |                                          |            | to establish a powerful approach to      |                                          |                    |
# |                      |                                          |                                          |                                          |            | elucidate the cellular and molecular     |                                          |                    |
# |                      |                                          |                                          |                                          |            | details regarding the pathogenesis of    |                                          |                    |
# |                      |                                          |                                          |                                          |            | MHV induced neurological dystrophy. My   |                                          |                    |
# |                      |                                          |                                          |                                          |            | long term goal is to extend these        |                                          |                    |
# |                      |                                          |                                          |                                          |            | studies to search for similarities in    |                                          |                    |
# |                      |                                          |                                          |                                          |            | mechanistic pathways of the inflammatory |                                          |                    |
# |                      |                                          |                                          |                                          |            | processes associated with autoimmune     |                                          |                    |
# |                      |                                          |                                          |                                          |            | diseases such as multiple sclerosis,     |                                          |                    |
# |                      |                                          |                                          |                                          |            | neurodegenerative diseases such as       |                                          |                    |
# |                      |                                          |                                          |                                          |            | Alzheimer’s and Parkinson’s disease, and |                                          |                    |
# |                      |                                          |                                          |                                          |            | other infectious diseases. The insights  |                                          |                    |
# |                      |                                          |                                          |                                          |            | from my studies will provide me proper   |                                          |                    |
# |                      |                                          |                                          |                                          |            | knowledge and expertise to meet the      |                                          |                    |
# |                      |                                          |                                          |                                          |            | challenge of future emerging neurotropic |                                          |                    |
# |                      |                                          |                                          |                                          |            | viruses and viral diseases.              |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Anuradha Bhat        | Professor, IISER Kolkata      (current)  | PhD (Ecological Sciences), Indian        | PhD (Ecological Sciences), Indian        |       2002 | My research interested are in the        | Small Research Grant from Fisheries      | 2.0                |
# |                      | Associate Professor, IISER Kolkata       | Institute of Science, 2002               | Institute of Science                     |            | following broad areas:1) Ecology:        | Society of the British Isles (2005)      |                    |
# |                      | (2018 - 2024) Assistant Professor, IISER |                                          |                                          |            | Community ecology and distribution       | Royal Society (India) International      |                    |
# |                      | Kolkata     (2010 - 2018) Teaching       |                                          |                                          |            | patterns of freshwater fish in tropical  | Fellowship from Royal Society, UK (2004) |                    |
# |                      | Fellow, University of St Andrews         |                                          |                                          |            | ecosystems 2) Behaviour and Evolution:   |                                          |                    |
# |                      | (2009 - 2010) Postdoctoral Research      |                                          |                                          |            | population variations in behavioural     |                                          |                    |
# |                      | Scholar, Indiana University, USA         |                                          |                                          |            | traits among wild zebrafish populations  |                                          |                    |
# |                      | (2006 - 2008) Royal Society              |                                          |                                          |            | and its evolutionary implications3)      |                                          |                    |
# |                      | (International) Fellow, University of St |                                          |                                          |            | Conservation of fish and tropical stream |                                          |                    |
# |                      | Andrews, UK     (2004 - 2005)            |                                          |                                          |            | systems: statistical and modeling        |                                          |                    |
# |                      |                                          |                                          |                                          |            | methods in developing conservation       |                                          |                    |
# |                      |                                          |                                          |                                          |            | strategies                               |                                          |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# | Amirul Islam Mallick | Professor, IISER Kolkata      (current)  | PhD (Biotechnology), Interdisciplinary   | PhD (Biotechnology), Interdisciplinary   |       2008 | My research focuses on studying host-    | Scientific High Level Visiting           | 11.0               |
# |                      | Associate Professor, Indian Institute of | Biotechnology Unit (Aligarh Muslim       | Biotechnology Unit (Aligarh Muslim       |            | pathogen interaction at the mucosal      | Fellowships (SSHN)-2024 from Indian      |                    |
# |                      | Science, Education and Research Kolkata  | University), 2008, Specialization in     | University)                              |            | surface and investigating the role of    | French Institute (2024) The Royal        |                    |
# |                      | (2019 - 2025) Assistant Professor,       | Molecular Immunology MVSc (Microbiology  |                                          |            | differential host responses against gut  | Society-BactiVac UK Travel Bursary award |                    |
# |                      | Indian Institute of Science Education    | and Immunology), Mathura Veterinary      |                                          |            | pathogens. Since effective host          | from The Royal Society, UK (2024) IVI    |                    |
# |                      | and Research Kolkata      (2014 - 2019)  | College (CSA University of Agriculture & |                                          |            | responses at the mucosal surface can be  | Course Fellow from International Vaccine |                    |
# |                      | Post Doctoral Fellow, Sunnybrook         | Technology, Kanpur), 2003 BVSc and A.H.  |                                          |            | achieved by directing memory and         | Institute, South Korea (2022) ICMR-DHR   |                    |
# |                      | Research Institute, University of        | (Veterinary Medicine), Veterinary and    |                                          |            | effector immune cells to the mucosal     | International Fellow from Indian Council |                    |
# |                      | Toronto, ON, Canada     (2010 - 2014)    | Animal Scs. (West Bengal University of   |                                          |            | membranes through tissue-specific homing | of Medical Research (2019) Early Career  |                    |
# |                      | Post Doctoral Fellow, Ontario Veterinary | Animal & Fishery Scs,Kol), 2001          |                                          |            | receptors, my research group is          | Research Award from SCIENCE &            |                    |
# |                      | College, University of Guelph, Canada    |                                          |                                          |            | interested in understanding the          | ENGINEERING RESEARCH BOARD (SERB), India |                    |
# |                      | (2008 - 2010)                            |                                          |                                          |            | contributions of the individual host     | (2016) Canadian Breast Cancer Foundation |                    |
# |                      |                                          |                                          |                                          |            | cell types and molecules towards         | Fellowship from Canadian Breast Cancer   |                    |
# |                      |                                          |                                          |                                          |            | infection and immunity. More             | Foundation  (2012) ICI - CSI             |                    |
# |                      |                                          |                                          |                                          |            | specifically, we try to underpin how the | International Travel Award from          |                    |
# |                      |                                          |                                          |                                          |            | virulence repertories of emerging        | International Congress of Immunology     |                    |
# |                      |                                          |                                          |                                          |            | mucosal pathogens such as the Influenza  | (ICI) and Canadian Society for           |                    |
# |                      |                                          |                                          |                                          |            | virus and Campylobacter jejuni induce    | Immunology (CSI) (2010) Senior Research  |                    |
# |                      |                                          |                                          |                                          |            | biologically relevant host responses.    | Fellowship from Council of Scientific    |                    |
# |                      |                                          |                                          |                                          |            |                                          | and Industrial Research (CSIR), New      |                    |
# |                      |                                          |                                          |                                          |            |                                          | Delhi  (2006) Post Graduate merit        |                    |
# |                      |                                          |                                          |                                          |            |                                          | scholarship from CSA University of Agrl. |                    |
# |                      |                                          |                                          |                                          |            |                                          | and Technol, Kapnur (2001) National      |                    |
# |                      |                                          |                                          |                                          |            |                                          | Merit Scholarship from Ministry of Human |                    |
# |                      |                                          |                                          |                                          |            |                                          | Resource Development, Government of      |                    |
# |                      |                                          |                                          |                                          |            |                                          | India (1996)                             |                    |
# +----------------------+------------------------------------------+------------------------------------------+------------------------------------------+------------+------------------------------------------+------------------------------------------+--------------------+
# /tmp/ipython-input-2087774443.py:26: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_to_print.fillna('', inplace=True)

# %%
# Convert columns to numeric, forcing any errors (like stray text) into 'NaN'
df['PhD_Year'] = pd.to_numeric(df['PhD_Year'], errors='coerce')
df['Number_of_awards'] = pd.to_numeric(df['Number_of_awards'], errors='coerce')
df['No_of_publications'] = pd.to_numeric(df['No_of_publications'], errors='coerce')

# df = pd.read_sql_query("SELECT * FROM Faculty", conn) # Removed this line
print(df[['Name', 'No_of_publications']])

# --- Imports ---
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Already imported, but good practice
# Out:
#                     Name  No_of_publications
# 0      Amit Kumar Mandal                   0
# 1              Rahul Das                  30
# 2            Arnab Gupta                   3
# 3   Robert John Chandran                  11
# 4          Bidisha Sinha                   0
# 5    Rituparna Sinha Roy                   0
# 6   Tapas Kumar Sengupta                   6
# 7           Mohit Prasad                   0
# 8    Neelanjana Sengupta                   0
# 9          Anuradha Bhat                   0
# 10     Sumit Sen Santara                  15
# 11          Dipjyoti Das                  13
# 12       Annagiri Sumana                  10
# 13  Sreeramaiah Gangappa                   5
# 14   Partha Pratim Datta                   0
# 15           Rupak Datta                   0
# 16     Sunil Kumar Khare                   0
# 17       Babu Sudhamalla                  28
# 18       Anindita Bhadra                   0
# 19    Radhika Venkatesan                   0
# 20           Malancha Ta                  15
# 21          Sankar Maiti                   3
# 22    Partho Sarothi Ray                  22
# 23        Supratim Datta                  28
# 24  Amirul Islam Mallick                   0
# 25     Jayasri Das Sarma                  22
# 26    Punyasloke Bhadury                  78

# %%
# Create a DataFrame for the awards plot, dropping rows with missing data
df_awards_plot = df.dropna(subset=['PhD_Year', 'Number_of_awards'])

# Get the x and y values for awards
x_data_awards = df_awards_plot['PhD_Year']
y_data_awards = df_awards_plot['Number_of_awards']

# --- Plotting ---
plt.figure(figsize=(10, 6))
plt.scatter(x_data_awards, y_data_awards, label='Data Points')

# --- Calculate and plot the trend line ---
m_awards, b_awards = np.polyfit(x_data_awards, y_data_awards, 1)
plt.plot(x_data_awards, m_awards * x_data_awards + b_awards, color='black', alpha=1, label='Fitted Line')

# --- Add labels and title ---
plt.title('Distribution of Awards by PhD Year', fontsize=16)
plt.xlabel('Year of PhD Completion', fontsize=12)
plt.ylabel('Number of Awards', fontsize=12)

# Add text for slope and intercept
plt.text(1990, 2, f'Slope: {m_awards:.2f}', fontsize=12)
plt.text(1990, 1.9, f'Intercept: {b_awards:.2f}', fontsize=12)

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Create a DataFrame for this plot, dropping rows with missing data
df_pubs_plot = df.dropna(subset=['PhD_Year', 'No_of_publications'])

# Get the x and y values
x_data_pubs = df_pubs_plot['PhD_Year']
y_data_pubs = df_pubs_plot['No_of_publications']

# --- Plotting ---
plt.figure(figsize=(10, 6))
plt.scatter(x_data_pubs, y_data_pubs, label='Data Points') # Create the scatter plot

# --- Calculate and plot the trend line ---
m_pubs, b_pubs = np.polyfit(x_data_pubs, y_data_pubs, 1)
plt.plot(x_data_pubs, m_pubs * x_data_pubs + b_pubs, color='black', alpha=1, label='Fitted Line')

# --- Add labels and title ---
plt.title('Distribution of Publications by PhD Year', fontsize=16)
plt.xlabel('Year of PhD Completion', fontsize=12)
plt.ylabel('Number of Publications', fontsize=12)

# Add text for slope and intercept [cite: 234, 236]
plt.text(1990, 2, f'Slope: {m_pubs:.2f}', fontsize=12)
plt.text(1990, 1.9, f'Intercept: {b_pubs:.2f}', fontsize=12)

plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
